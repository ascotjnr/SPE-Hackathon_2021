# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import time
import numpy as np
# %matplotlib inline
import lasio

# Hide Warnings
import warnings
warnings.filterwarnings("ignore")

# %config InlineBackend.figure_format='svg' # To create high resolution images

# %%
filename_input = r"C:\Users\User\Desktop\Wells\P02_welltest.txt"

# %%
df_P02 = pd.read_csv(filename_input, delim_whitespace=True)
df_P02.head(10)
# Out:
#                            @@@   Well-test report, powered         by  \
# @@@                    Special     edition     for     SPE  GeoEnergy
# Well                     name:         P02     NaN     NaN        NaN
# Perforation          interval:        2137      to    2211        NaN
# Fluid                       in      place:   brine     NaN        NaN
# Initial              pressure:     209.214     NaN     NaN        NaN
# Temperature:           347.412         NaN     NaN     NaN        NaN
# time(day)     water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 0.000002               200.000  209.036373     NaN     NaN        NaN
# 0.000004               200.000  209.035911     NaN     NaN        NaN
# 0.000006               200.000  209.035314     NaN     NaN        NaN
#
#                   DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# @@@           Hackathon                            2021.0   @@@
# Well                NaN                               NaN   NaN
# ...

# %%
df_P02 = df_P02.reset_index()
df_P02.head(10)
# Out:
#           index               @@@   Well-test report, powered         by  \
# 0           @@@           Special     edition     for     SPE  GeoEnergy
# 1          Well             name:         P02     NaN     NaN        NaN
# 2   Perforation         interval:        2137      to    2211        NaN
# 3         Fluid                in      place:   brine     NaN        NaN
# 4       Initial         pressure:     209.214     NaN     NaN        NaN
# 5  Temperature:           347.412         NaN     NaN     NaN        NaN
# 6     time(day)  water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 7      0.000002           200.000  209.036373     NaN     NaN        NaN
# 8      0.000004           200.000  209.035911     NaN     NaN        NaN
# 9      0.000006           200.000  209.035314     NaN     NaN        NaN
#
#        DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# 0  Hackathon                            2021.0   @@@
# 1        NaN                               NaN   NaN
# ...

# %%
df_P02 = df_P02.drop(df_P02.index[:7])
df_P02.head(10)
# Out:
#        index      @@@   Well-test report, powered   by DARTS  \
# 7   0.000002  200.000  209.036373     NaN     NaN  NaN   NaN
# 8   0.000004  200.000  209.035911     NaN     NaN  NaN   NaN
# 9   0.000006  200.000  209.035314     NaN     NaN  NaN   NaN
# 10  0.000009  200.000  209.034550     NaN     NaN  NaN   NaN
# 11  0.000013  200.000  209.033579     NaN     NaN  NaN   NaN
# 12  0.000018  200.000  209.032349     NaN     NaN  NaN   NaN
# 13  0.000024  200.000  209.030801     NaN     NaN  NaN   NaN
# 14  0.000032  200.000  209.028870     NaN     NaN  NaN   NaN
# 15  0.000043  200.000  209.026482     NaN     NaN  NaN   NaN
# 16  0.000056  200.000  209.023558     NaN     NaN  NaN   NaN
#
#     (https://darts.citg.tudelft.nl/) @@@.1
# 7                                NaN   NaN
# 8                                NaN   NaN
# 9                                NaN   NaN
# 10                               NaN   NaN
# 11                               NaN   NaN
# ...

# %%
df_P02 = df_P02.drop(df_P02.columns[[3,4,5,6,7,8]], axis=1)  # df.columns is zero-based pd.Index
df_P02.head()
# Out:
#        index      @@@   Well-test
# 7   0.000002  200.000  209.036373
# 8   0.000004  200.000  209.035911
# 9   0.000006  200.000  209.035314
# 10  0.000009  200.000  209.034550
# 11  0.000013  200.000  209.033579

# %%
df_P02=pd.DataFrame(df_P02)

# %%
# store dataframe into csv file

df_P02.to_csv('Well_P02.csv', index=False)

# %%
# store dataframe into excel file

df_P02.to_excel("Well_P02.xlsx", index=False)

# %%
filename = r"C:\Users\User\Desktop\Wells\Well_P02.csv"

colnames=['time', 'water_rate', 'BHP'] 

df_P02 = pd.read_csv(filename, names=colnames, header=None)
df_P02.head(20)
# Out:
#         time water_rate         BHP
# 0      index        @@@   Well-test
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558
# 11  0.000074    200.000  209.020020
# 12  0.000098    200.000  209.015789
# 13  0.000128    200.000  209.010791
# 14  0.000167    200.000  209.004958
# 15  0.000218    200.000  208.998230
# 16  0.000285    200.000  208.990566
# 17  0.000372    200.000  208.981961
# 18  0.000484    200.000  208.972466
# 19  0.000630    200.000  208.962209

# %%
df_P02 = df_P02.drop(0)
df_P02.head(10)
# Out:
#         time water_rate         BHP
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558

# %%
filename_input = r"C:\Users\User\Desktop\Wells\P03_welltest.txt"

# %%
df_P03 = pd.read_csv(filename_input, delim_whitespace=True)
df_P03.head(10)
# Out:
#                            @@@   Well-test report, powered         by  \
# @@@                    Special     edition     for     SPE  GeoEnergy
# Well                     name:         P03     NaN     NaN        NaN
# Perforation          interval:        2060      to    2200        NaN
# Fluid                       in      place:   brine     NaN        NaN
# Initial              pressure:     210.289     NaN     NaN        NaN
# Temperature:           350.285         NaN     NaN     NaN        NaN
# time(day)     water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 0.000001               200.000  210.214512     NaN     NaN        NaN
# 0.000002               200.000  210.214286     NaN     NaN        NaN
# 0.000004               200.000  210.214087     NaN     NaN        NaN
#
#                   DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# @@@           Hackathon                            2021.0   @@@
# Well                NaN                               NaN   NaN
# ...

# %%
df_P03 = df_P03.reset_index()
df_P03.head(10)
# Out:
#           index               @@@   Well-test report, powered         by  \
# 0           @@@           Special     edition     for     SPE  GeoEnergy
# 1          Well             name:         P03     NaN     NaN        NaN
# 2   Perforation         interval:        2060      to    2200        NaN
# 3         Fluid                in      place:   brine     NaN        NaN
# 4       Initial         pressure:     210.289     NaN     NaN        NaN
# 5  Temperature:           350.285         NaN     NaN     NaN        NaN
# 6     time(day)  water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 7      0.000001           200.000  210.214512     NaN     NaN        NaN
# 8      0.000002           200.000  210.214286     NaN     NaN        NaN
# 9      0.000004           200.000  210.214087     NaN     NaN        NaN
#
#        DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# 0  Hackathon                            2021.0   @@@
# 1        NaN                               NaN   NaN
# ...

# %%
df_P03 = df_P03.drop(df_P03.index[:7])
df_P03.head(10)
# Out:
#        index      @@@   Well-test report, powered   by DARTS  \
# 7   0.000001  200.000  210.214512     NaN     NaN  NaN   NaN
# 8   0.000002  200.000  210.214286     NaN     NaN  NaN   NaN
# 9   0.000004  200.000  210.214087     NaN     NaN  NaN   NaN
# 10  0.000006  200.000  210.213830     NaN     NaN  NaN   NaN
# 11  0.000009  200.000  210.213500     NaN     NaN  NaN   NaN
# 12  0.000013  200.000  210.213076     NaN     NaN  NaN   NaN
# 13  0.000018  200.000  210.212534     NaN     NaN  NaN   NaN
# 14  0.000024  200.000  210.211844     NaN     NaN  NaN   NaN
# 15  0.000032  200.000  210.210972     NaN     NaN  NaN   NaN
# 16  0.000043  200.000  210.209877     NaN     NaN  NaN   NaN
#
#     (https://darts.citg.tudelft.nl/) @@@.1
# 7                                NaN   NaN
# 8                                NaN   NaN
# 9                                NaN   NaN
# 10                               NaN   NaN
# 11                               NaN   NaN
# ...

# %%
df_P03 = df_P03.drop(df_P03.columns[[3,4,5,6,7,8]], axis=1)  # df.columns is zero-based pd.Index
df_P03.head()
# Out:
#        index      @@@   Well-test
# 7   0.000001  200.000  210.214512
# 8   0.000002  200.000  210.214286
# 9   0.000004  200.000  210.214087
# 10  0.000006  200.000  210.213830
# 11  0.000009  200.000  210.213500

# %%
df_P03=pd.DataFrame(df_P03)

# %%
# store dataframe into csv file

df_P03.to_csv('Well_P03.csv', index=False)

# %%
filename = r"C:\Users\User\Desktop\Wells\Well_P02.csv"

colnames=['time', 'water_rate', 'BHP'] 

df_P03 = pd.read_csv(filename, names=colnames, header=None)
df_P03.head(20)
# Out:
#         time water_rate         BHP
# 0      index        @@@   Well-test
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558
# 11  0.000074    200.000  209.020020
# 12  0.000098    200.000  209.015789
# 13  0.000128    200.000  209.010791
# 14  0.000167    200.000  209.004958
# 15  0.000218    200.000  208.998230
# 16  0.000285    200.000  208.990566
# 17  0.000372    200.000  208.981961
# 18  0.000484    200.000  208.972466
# 19  0.000630    200.000  208.962209

# %%
df_P03 = df_P03.drop(0)
df_P03.head(10)
# Out:
#         time water_rate         BHP
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558

# %%
# store dataframe into csv file

df_P03.to_csv('Well_P03.csv', index=False)

# %%
filename_input = r"C:\Users\User\Desktop\Wells\I02_welltest.txt"

# %%
df_I02 = pd.read_csv(filename_input, delim_whitespace=True)
df_I02.head(10)
# Out:
#                            @@@   Well-test report, powered         by  \
# @@@                    Special     edition     for     SPE  GeoEnergy
# Well                     name:         P03     NaN     NaN        NaN
# Perforation          interval:        2060      to    2200        NaN
# Fluid                       in      place:   brine     NaN        NaN
# Initial              pressure:     210.289     NaN     NaN        NaN
# Temperature:           350.285         NaN     NaN     NaN        NaN
# time(day)     water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 0.000001               200.000  210.214512     NaN     NaN        NaN
# 0.000002               200.000  210.214286     NaN     NaN        NaN
# 0.000004               200.000  210.214087     NaN     NaN        NaN
#
#                   DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# @@@           Hackathon                            2021.0   @@@
# Well                NaN                               NaN   NaN
# ...

# %%
df_I02 = df_I02.reset_index()
df_I02.head(10)
# Out:
#           index               @@@   Well-test report, powered         by  \
# 0           @@@           Special     edition     for     SPE  GeoEnergy
# 1          Well             name:         P03     NaN     NaN        NaN
# 2   Perforation         interval:        2060      to    2200        NaN
# 3         Fluid                in      place:   brine     NaN        NaN
# 4       Initial         pressure:     210.289     NaN     NaN        NaN
# 5  Temperature:           350.285         NaN     NaN     NaN        NaN
# 6     time(day)  water_rate(m3/d)   BHP(bars)     NaN     NaN        NaN
# 7      0.000001           200.000  210.214512     NaN     NaN        NaN
# 8      0.000002           200.000  210.214286     NaN     NaN        NaN
# 9      0.000004           200.000  210.214087     NaN     NaN        NaN
#
#        DARTS  (https://darts.citg.tudelft.nl/) @@@.1
# 0  Hackathon                            2021.0   @@@
# 1        NaN                               NaN   NaN
# ...

# %%
df_I02 = df_I02.drop(df_I02.index[:7])
df_I02.head(10)
# Out:
#        index      @@@   Well-test report, powered   by DARTS  \
# 7   0.000001  200.000  210.214512     NaN     NaN  NaN   NaN
# 8   0.000002  200.000  210.214286     NaN     NaN  NaN   NaN
# 9   0.000004  200.000  210.214087     NaN     NaN  NaN   NaN
# 10  0.000006  200.000  210.213830     NaN     NaN  NaN   NaN
# 11  0.000009  200.000  210.213500     NaN     NaN  NaN   NaN
# 12  0.000013  200.000  210.213076     NaN     NaN  NaN   NaN
# 13  0.000018  200.000  210.212534     NaN     NaN  NaN   NaN
# 14  0.000024  200.000  210.211844     NaN     NaN  NaN   NaN
# 15  0.000032  200.000  210.210972     NaN     NaN  NaN   NaN
# 16  0.000043  200.000  210.209877     NaN     NaN  NaN   NaN
#
#     (https://darts.citg.tudelft.nl/) @@@.1
# 7                                NaN   NaN
# 8                                NaN   NaN
# 9                                NaN   NaN
# 10                               NaN   NaN
# 11                               NaN   NaN
# ...

# %%
df_I02 = df_I02.drop(df_I02.columns[[3,4,5,6,7,8]], axis=1)  # df.columns is zero-based pd.Index
df_I02.head()
# Out:
#        index      @@@   Well-test
# 7   0.000001  200.000  210.214512
# 8   0.000002  200.000  210.214286
# 9   0.000004  200.000  210.214087
# 10  0.000006  200.000  210.213830
# 11  0.000009  200.000  210.213500

# %%
df_I02=pd.DataFrame(df_I02)

# %%
# store dataframe into csv file

df_I02.to_csv('Well_I02.csv', index=False)

# %%
filename = r"C:\Users\User\Desktop\Wells\Well_I02.csv"

colnames=['time', 'water_rate', 'BHP'] 

df_I02 = pd.read_csv(filename, names=colnames, header=None)
df_I02.head(20)
# Out:
#         time water_rate         BHP
# 0      index        @@@   Well-test
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558
# 11  0.000074    200.000  209.020020
# 12  0.000098    200.000  209.015789
# 13  0.000128    200.000  209.010791
# 14  0.000167    200.000  209.004958
# 15  0.000218    200.000  208.998230
# 16  0.000285    200.000  208.990566
# 17  0.000372    200.000  208.981961
# 18  0.000484    200.000  208.972466
# 19  0.000630    200.000  208.962209

# %%
df_I02 = df_I02.drop(0)
df_I02.head(10)
# Out:
#         time water_rate         BHP
# 1   0.000002    200.000  209.036373
# 2   0.000004    200.000  209.035911
# 3   0.000006    200.000  209.035314
# 4   0.000009    200.000  209.034550
# 5   0.000013    200.000  209.033579
# 6   0.000018    200.000  209.032349
# 7   0.000024    200.000  209.030801
# 8   0.000032    200.000  209.028870
# 9   0.000043    200.000  209.026482
# 10  0.000056    200.000  209.023558

# %%
# store dataframe into csv file

df_I02.to_csv('Well_I02.csv', index=False)

# %%
with pd.ExcelWriter('well tests.xlsx') as writer:  
    df_P02.to_excel(writer, sheet_name='Sheet_name_1')
    df_P03.to_excel(writer, sheet_name='Sheet_name_2')
    df_I02.to_excel(writer, sheet_name='Sheet_name_3')
